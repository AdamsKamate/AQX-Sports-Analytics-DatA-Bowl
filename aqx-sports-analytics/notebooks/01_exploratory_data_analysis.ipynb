# %%
import pandas as pd

# 1. Chargement des données
df = pd.read_csv('../data/raw/NBA Finals and MVP.csv', encoding='latin1')

# 2. Aperçu des 5 premières lignes
print("--- APERÇU DES DONNÉES ---")
display(df.head())

# 3. Informations sur les colonnes (types, valeurs nulles)
print("\n--- INFOS SUR LE DATASET ---")
df.info()

# 4. Statistiques descriptives
print("\n--- STATISTIQUES ---")
display(df.describe(include='all'))
# Out:
# --- APERÇU DES DONNÉES ---
#      Year    Western Champion    Eastern Champion Result        NBA Champion  \
# 0  1951.0    Rochester Royals     New York Knicks    43    Rochester Royals
# 1  1952.0  Minneapolis Lakers     New York Knicks    43  Minneapolis Lakers
# 2  1953.0  Minneapolis Lakers     New York Knicks    41  Minneapolis Lakers
# 3  1954.0  Minneapolis Lakers  Syracuse Nationals    43  Minneapolis Lakers
# 4  1955.0  Fort Wayne Pistons  Syracuse Nationals    34  Syracuse Nationals
#
#     NBA Vice-Champion Final Sweep ?      MVP Name  MVP Height (m)  \
# 0     New York Knicks         False   Ed Macauley            2.03
# 1     New York Knicks         False  Paul Arizin             1.93
# 2     New York Knicks         False  George Mikan            2.08
# 3  Syracuse Nationals         False      B. Cousy            1.85
# 4  Fort Wayne Pistons         False     B. Pettit            2.06
#
#    MVP Height (ft) MVP Position               MVP Team MVP Nationality  \
# ...
